# %%
# import project directory helper
import os, sys, inspect
currentDir = os.getcwd()
parentDir = os.path.dirname(currentDir)
sys.path.insert(0, parentDir)

# %%
# import pyspark packages
from pyspark import SparkContext as sc
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession, functions, types
from pyspark.sql.types import *

# %%
# import util packages
from datetime import datetime as dt
from IPython.display import display
import pandas as pd

# %%
spark = SparkSession.builder.appName('attraction').getOrCreate()

# %%
# define path
tripad_attr_path = parentDir + '/crawler/datasets/tripadvisor_dataset/attractions/'
parquet_path = parentDir + '/crawler/datasets/tripadvisor_dataset/spark/'

# %%
# read spark dataframe from parquet
final_attr_spark_df = spark.read.parquet(parquet_path + 'tripad_attr')

# %%
# visualize spark dataframe
display(final_attr_spark_df.count())
final_attr_spark_df.printSchema()
display(final_attr_spark_df.toPandas())
# Out:
# 4257
# root
#  |-- activityId: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#      activityId            city                   state   country  latitude  \
# 0      12962337    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 1      12905660    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 2      11807013    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 3      12471375    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4      12469580    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 5      16722683    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 6      11454341            Kuah                Langkawi  Malaysia  6.326672
# 7      11812460    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 8      11992275            Kuah                Langkawi  Malaysia  6.326672
# 9      11991123   Penang Island                  Penang  Malaysia  5.388071
# 10     11482502    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 11     19350513  Batu Ferringhi           Penang Island  Malaysia  5.471783
# 12     11474972     George Town           Penang Island  Malaysia  5.411938
# 13     12648212   Kota Kinabalu  Kota Kinabalu District  Malaysia  5.979383
# 14     11470871    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 15     12468200    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 16     12934938        Sandakan       Sandakan Division  Malaysia  5.838944
# 17     11452959    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 18     16749910        Langkawi       Langkawi District  Malaysia  6.351074
# 19     12939362        Sandakan       Sandakan Division  Malaysia  5.838944
# 20     15135878   Kota Kinabalu  Kota Kinabalu District  Malaysia  5.979383
# 21     15142299   Kota Kinabalu  Kota Kinabalu District  Malaysia  5.979383
# 22     11449679    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 23     15830443   Penang Island                  Penang  Malaysia  5.388071
# 24     11484318   Petaling Jaya       Petaling District  Malaysia   3.10363
# 25     16939354    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 26     14061658        Langkawi       Langkawi District  Malaysia  6.351074
# 27     17718163     George Town           Penang Island  Malaysia  5.411938
# 28     11475887       Cherating        Kuantan District  Malaysia  4.133792
# 29     17419599    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# ...         ...             ...                     ...       ...       ...
# 4227   17685131    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4228   13807388    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4229   14017942    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4230   14779089    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4231   17847022     Johor Bahru    Johor Bahru District  Malaysia  1.473394
# 4232   17847038    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4233   17847107  Batu Ferringhi           Penang Island  Malaysia  5.471783
# 4234   11479905    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4235   14025818    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4236   17329973   Petaling Jaya       Petaling District  Malaysia   3.10363
# 4237   17019216  Batu Ferringhi           Penang Island  Malaysia  5.471783
# 4238   17019215  Batu Ferringhi           Penang Island  Malaysia  5.471783
# 4239   12470359  Batu Ferringhi           Penang Island  Malaysia  5.471783
# 4240   14787807    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
# 4241   12467426         Sarawak                Malaysia  Malaysia  2.310777
# 4242   11464516    Kuala Lumpur     Wilayah Persekutuan  Malaysia  3.156802
#
# 4231  103.75248  Private Photo Session with a Local Photographe...  1008.66
# 4232  101.69717  Private Photo Session with a Local Photographe...  1008.66
# 4233  100.24629  Private Photo Session with a Local Photographe...  1008.66
# 4234  101.69717  Private Tour: Historical Malacca Trip from Kua...   391.50
# 4235  101.69717  Guided Eco Ride Tour of City in the Garden Put...   480.10
# 4236  101.64778                    Sky Mirror and Paddy Field Tour   391.50
# 4237  100.24629   Team Building & Activities Heritage City Penang    267.87
# 4238  100.24629            Team Building & Activities Beach Penang   304.96
# 4239  100.24629        Private Half-Day Penang Cultural Experience   133.93
# 4240  101.69717  Kuala Lumpur Cruise Layover Tour from Boustead...   387.38
# 4241  112.50697             Half-Day Sightseeing Tour of Miri City   182.11
# 4242  101.69717  Taman Negara National Park + Cameron Highlands...  2616.87
# 4243  101.69717        Full-Day Kuala Lumpur Grand Tour with Lunch   247.26
# 4244  101.69717           Malaysian Cultural Night in Kuala Lumpur   247.26
# 4245  101.69717  Half-Day City Tour with Kuala Lumpur Tower Adm...   226.66
# 4246  101.69717  Escape Room: Malaysia's First Real Life Escape...    33.38
# 4247  101.69717         Private Kuala Lumpur Heritage Walking Tour   164.84
# 4248  101.69717  Cameron Highlands Day Tour Strawberry Park, Te...   576.95
# 4249  101.69717        Historical Malacca Full-day Tour with Lunch   366.77
# 4250  101.64778          4G WiFi (MY Airport Pick Up) for Malaysia    34.41
# 4251  103.75248                         5D Studio Admission Ticket    22.86
# 4252  99.843025                    6D Cinemotion Admission Ticket     19.05
# 4253  101.69717                             Kuala Lumpur City Tour    98.91
# 4254  101.69717    Kuala Lumpur City Tour + Batu cave Tour - 1 Day   576.95
# 4255  100.24629                                Penang Amazing Race   267.87
# 4256  110.35362  Mangrove & Irrawaddy Dolphin Watching Cruise f...   230.78
#
#       rating                                           category
# 0        4.5  [featured_tours_and_tickets, luxury_special_oc...
# 1        4.0  [featured_tours_and_tickets, sightseeing_ticke...
# 2        4.5  [featured_tours_and_tickets, private_custom_to...
# 3        4.5  [featured_tours_and_tickets, luxury_special_oc...
# 4        4.0  [featured_tours_and_tickets, luxury_special_oc...
# 5        3.0    [featured_tours_and_tickets, tours_sightseeing]
# 6        5.0  [featured_tours_and_tickets, water_sports, tou...
# 7        5.0  [featured_tours_and_tickets, private_custom_to...
# 8        5.0   [featured_tours_and_tickets, outdoor_activities]
# 9        4.5  [featured_tours_and_tickets, walking_biking_to...
# 10       5.0  [featured_tours_and_tickets, classes_workshops...
# 11       5.0  [featured_tours_and_tickets, food_wine_nightlife]
# 12       5.0  [featured_tours_and_tickets, walking_biking_to...
# 13       4.5  [featured_tours_and_tickets, cruises_sailing_w...
# 14       5.0  [featured_tours_and_tickets, luxury_special_oc...
# 15       5.0  [featured_tours_and_tickets, private_custom_to...
# 16       5.0  [featured_tours_and_tickets, multiday_extended...
# 17       5.0  [featured_tours_and_tickets, walking_biking_to...
# 18       4.0  [featured_tours_and_tickets, shore_excursions,...
# 19       4.5  [featured_tours_and_tickets, private_custom_to...
# 20       4.5  [featured_tours_and_tickets, water_sports, tou...
# 21       4.5  [featured_tours_and_tickets, outdoor_activitie...
# 22       3.5  [featured_tours_and_tickets, tours_sightseeing...
# 23       5.0   [featured_tours_and_tickets, outdoor_activities]
# 24       4.0  [featured_tours_and_tickets, theme_parks, outd...
# 25       4.0  [featured_tours_and_tickets, luxury_special_oc...
# 26       2.5  [featured_tours_and_tickets, day_trips_excursi...
# 27       5.0  [featured_tours_and_tickets, private_custom_to...
# 28       4.5  [featured_tours_and_tickets, outdoor_activitie...
# 29       5.0  [featured_tours_and_tickets, food_wine_nightli...
# ...      ...                                                ...
# 4227    -1.0                                [tours_sightseeing]
# 4228     5.0                                [tours_sightseeing]
# 4229    -1.0                                [tours_sightseeing]
# 4230    -1.0                                [tours_sightseeing]
# 4231    -1.0                                [tours_sightseeing]
# 4232    -1.0                                [tours_sightseeing]
# 4233    -1.0                                [tours_sightseeing]
# 4234     5.0                                [tours_sightseeing]
# 4235    -1.0                                [tours_sightseeing]
# 4236    -1.0                                [tours_sightseeing]
# 4237    -1.0                                [tours_sightseeing]
# 4238    -1.0                                [tours_sightseeing]
# 4239    -1.0                                [tours_sightseeing]
# 4240    -1.0             [tours_sightseeing, tours_sightseeing]
# 4241     4.0                                [tours_sightseeing]
# 4242    -1.0                                [tours_sightseeing]
# 4243     3.5                                [tours_sightseeing]
# 4244     4.0                                [tours_sightseeing]
# 4245    -1.0                                [tours_sightseeing]
# 4246     4.5                                [tours_sightseeing]
# 4247    -1.0                                [tours_sightseeing]
# 4248    -1.0                                [tours_sightseeing]
# 4249    -1.0                                [tours_sightseeing]
# 4250    -1.0                                [tours_sightseeing]
# 4251    -1.0                                [tours_sightseeing]
# 4252    -1.0                                [tours_sightseeing]
# 4253     2.5                                [tours_sightseeing]
# 4254     5.0                                [tours_sightseeing]
# 4255     1.0                                [tours_sightseeing]
# 4256     5.0                                [tours_sightseeing]
#
# [4257 rows x 10 columns]

# %%
# show null row from spark dataframe basec on specific column
final_attr_spark_df.where(final_attr_spark_df.rating.isNull()).show()
final_attr_spark_df.count()
# Out:
# +----------+----+-----+-------+--------+---------+----+-----+------+--------+
# |activityId|city|state|country|latitude|longitude|name|price|rating|category|
# +----------+----+-----+-------+--------+---------+----+-----+------+--------+
# +----------+----+-----+-------+--------+---------+----+-----+------+--------+
# 4257

# %%
# set a constant or literal value to null fields (for showing, if needed update as required)
temp_spark_df = final_attr_spark_df.where(
    final_attr_spark_df.rating.isNull()).withColumn("rating",
                                                    functions.lit(-1))

final_attr_spark_df = final_attr_spark_df.where(
    final_attr_spark_df.rating.isNotNull()).union(temp_spark_df)
final_attr_spark_df.count()
# Out:
# 4257

# %%
# create spark user defined function
clean_string_udf = functions.udf(lambda x: '_'.join(x.split(' ')).lower(), StringType())

# %%
# final_attr_spark_df = final_attr_spark_df.withColumn(
#     'city', clean_string_udf(final_attr_spark_df.city))

# %%
# create table or view from spark dataframe
final_attr_spark_df.createOrReplaceTempView('final_attr_spark_df')

# %% [markdown]
# # Processing rating

# %%
attr_rating_spark_df = final_attr_spark_df

# %%
avg_rat_spark_df = spark.sql(
    "SELECT city, category, AVG(rating) as avg_rating FROM final_attr_spark_df GROUP BY city, category"
)
avg_rat_spark_df.show()
# Out:
# +--------------+--------------------+------------------+
# |          city|            category|        avg_rating|
# +--------------+--------------------+------------------+
# |    port_klang|[weddings_honeymo...|              -1.0|
# |  kuala_lumpur|[shopping_fashion...|              -1.0|
# |          kuah|[private_custom_t...|              -1.0|
# |         klang|[transfers_ground...|              -1.0|
# |   bayan_lepas|[transfers_ground...|               3.5|
# | pantai_cenang|[cruises_sailing_...|              -1.0|
# |      langkawi|[family_friendly,...|2.1666666666666665|
# |        pahang|[food_wine_nightl...|              -1.0|
# |  kuala_lumpur|[luxury_special_o...|0.6578947368421053|
# |         klang|[shore_excursions...|              -1.0|
# |      langkawi|[food_wine_nightl...|               1.0|
# |   george_town|[shore_excursions...|              -1.0|
# |   george_town|[luxury_special_o...|               0.8|
# |        melaka| [tours_sightseeing]|              -1.0|
# |kuala_selangor|[day_trips_excurs...|              -1.0|
# |        sepang|[multiday_extende...|              -1.0|
# | kota_kinabalu|[cruises_sailing_...|              -1.0|
# |     singapore|[multiday_extende...|               3.5|
# |  kuala_lumpur|[walking_biking_t...|               3.5|
# |  kuala_lumpur|[shopping_fashion...|              -1.0|
# +--------------+--------------------+------------------+
# only showing top 20 rows

# %%
def roundTo5(x, base=.5):
    return float(round(x / base) * base)
round_to_5_udf = functions.udf(lambda x: roundTo5(x), DoubleType())

# %%
avg_rat_spark_df = avg_rat_spark_df.withColumn(
    'updated_rating', round_to_5_udf(avg_rat_spark_df.avg_rating))
avg_rat_spark_df.show()
# Out:
# +--------------+--------------------+------------------+--------------+
# |          city|            category|        avg_rating|updated_rating|
# +--------------+--------------------+------------------+--------------+
# |    port_klang|[weddings_honeymo...|              -1.0|          -1.0|
# |  kuala_lumpur|[shopping_fashion...|              -1.0|          -1.0|
# |          kuah|[private_custom_t...|              -1.0|          -1.0|
# |         klang|[transfers_ground...|              -1.0|          -1.0|
# |   bayan_lepas|[transfers_ground...|               3.5|           3.5|
# | pantai_cenang|[cruises_sailing_...|              -1.0|          -1.0|
# |      langkawi|[family_friendly,...|2.1666666666666665|           2.0|
# |        pahang|[food_wine_nightl...|              -1.0|          -1.0|
# |  kuala_lumpur|[luxury_special_o...|0.6578947368421053|           0.5|
# |         klang|[shore_excursions...|              -1.0|          -1.0|
# |      langkawi|[food_wine_nightl...|               1.0|           1.0|
# |   george_town|[shore_excursions...|              -1.0|          -1.0|
# |   george_town|[luxury_special_o...|               0.8|           1.0|
# |        melaka| [tours_sightseeing]|              -1.0|          -1.0|
# |kuala_selangor|[day_trips_excurs...|              -1.0|          -1.0|
# |        sepang|[multiday_extende...|              -1.0|          -1.0|
# | kota_kinabalu|[cruises_sailing_...|              -1.0|          -1.0|
# |     singapore|[multiday_extende...|               3.5|           3.5|
# |  kuala_lumpur|[walking_biking_t...|               3.5|           3.5|
# |  kuala_lumpur|[shopping_fashion...|              -1.0|          -1.0|
# +--------------+--------------------+------------------+--------------+
# only showing top 20 rows

# %%
attr_rating_spark_df = attr_rating_spark_df.join(avg_rat_spark_df,
                                                 ['city', 'category'], 'left')

# %%
attr_rating_spark_df = attr_rating_spark_df.withColumn(
    "rating",
    functions.when(attr_rating_spark_df["rating"] == -1,
                   attr_rating_spark_df["updated_rating"]).otherwise(
                       attr_rating_spark_df["rating"])).drop(
                           'updated_rating', 'avg_rating')

# %%
# show null row from spark dataframe basec on specific column
attr_rating_spark_df.where(attr_rating_spark_df.rating.isNull()).show()
attr_rating_spark_df.count()
# Out:
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# |city|category|activityId|state|country|latitude|longitude|name|price|rating|
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# 4257

# %%
display(attr_rating_spark_df.toPandas())
# Out:
#                 city                                           category  \
# 0        bayan_lepas                       [transfers_ground_transport]
# 1        bayan_lepas                       [transfers_ground_transport]
# 2              klang                       [transfers_ground_transport]
# 3              klang                       [transfers_ground_transport]
# 4               kuah  [private_custom_tours, luxury_special_occasion...
# 5       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 6       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 7      pantai_cenang  [cruises_sailing_water_tours, luxury_special_o...
# 8         port_klang                              [weddings_honeymoons]
# 9        george_town  [luxury_special_occasions, cultural_theme_tour...
# 10       george_town  [luxury_special_occasions, cultural_theme_tour...
# 11       george_town  [luxury_special_occasions, cultural_theme_tour...
# 12       george_town  [luxury_special_occasions, cultural_theme_tour...
# 13       george_town  [luxury_special_occasions, cultural_theme_tour...
# 14       george_town  [shore_excursions, luxury_special_occasions, d...
# 15             klang  [shore_excursions, day_trips_excursions, priva...
# 16             klang  [shore_excursions, day_trips_excursions, priva...
# 17             klang  [shore_excursions, day_trips_excursions, priva...
# 18             klang  [shore_excursions, day_trips_excursions, priva...
# 19             klang  [shore_excursions, day_trips_excursions, priva...
# 20             klang  [shore_excursions, day_trips_excursions, priva...
# 21             klang  [shore_excursions, day_trips_excursions, priva...
# 22             klang  [shore_excursions, day_trips_excursions, priva...
# 23             klang  [shore_excursions, day_trips_excursions, priva...
# 24             klang  [shore_excursions, day_trips_excursions, priva...
# 25             klang  [shore_excursions, day_trips_excursions, priva...
# 26             klang  [shore_excursions, day_trips_excursions, priva...
# 27             klang  [shore_excursions, day_trips_excursions, priva...
# 28             klang  [shore_excursions, day_trips_excursions, priva...
# 29             klang  [shore_excursions, day_trips_excursions, priva...
# ...              ...                                                ...
# 4227    kuala_lumpur  [private_custom_tours, cultural_theme_tours, t...
# 4228     pulau_carey                 [water_sports, outdoor_activities]
# 4229     george_town  [featured_tours_and_tickets, walking_biking_to...
# 4230   kota_kinabalu     [recommended_experiences, food_wine_nightlife]
# 4231            kuah  [water_sports, recommended_experiences, cruise...
# 4232    kuala_lumpur  [family_friendly, recommended_experiences, lux...
# 4233    kuala_lumpur  [outdoor_activities, luxury_special_occasions,...
# 4234    kuala_lumpur             [tours_sightseeing, tours_sightseeing]
# 4235          pahang  [recommended_experiences, sightseeing_tickets_...
# 4236      alor_setar                       [transfers_ground_transport]
# 4237   kota_kinabalu                               [outdoor_activities]
# 4238   kota_kinabalu                               [outdoor_activities]
# 4239   kota_kinabalu                               [outdoor_activities]
# 4240   kota_kinabalu                               [outdoor_activities]
# 4241   kota_kinabalu                               [outdoor_activities]
# 4242   kota_kinabalu                               [outdoor_activities]
# 4243   kota_kinabalu                               [outdoor_activities]
# 4244    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4245    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4246    kuala_lumpur  [walking_biking_tours, shore_excursions, outdo...
# 4247  kuala_selangor    [sightseeing_tickets_passes, tours_sightseeing]
# 4248          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4249          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4250          melaka  [shore_excursions, cultural_theme_tours, priva...
# 4251            miri  [cruises_sailing_water_tours, outdoor_activiti...
# 4252            miri                       [transfers_ground_transport]
# 4253            miri                       [transfers_ground_transport]
# 4254          penang  [local_experiences, food_wine_nightlife, tours...
# 4255   petaling_jaya  [shore_excursions, private_custom_tours, day_t...
# 4256       shah_alam  [theme_parks, sightseeing_tickets_passes, tour...
#
#      activityId                    state   country  latitude  longitude  \
# 0      19759004            Penang Island  Malaysia  5.294487  100.25968
# 1      19708737            Penang Island  Malaysia  5.294487  100.25968
# 2      19645570                 Selangor  Malaysia  3.039726  101.44049
# 3      19645571                 Selangor  Malaysia  3.039726  101.44049
# 4      13933745                 Langkawi  Malaysia  6.326672  99.843025
# 5      17516062      Wilayah Persekutuan  Malaysia  3.156802  101.69717
# 6      12965235      Wilayah Persekutuan  Malaysia  3.156802  101.69717
# 7      16861212                 Langkawi  Malaysia  6.290657   99.72765
# 8      15342175                 Selangor  Malaysia  2.999852  101.39283
# 9      16878593            Penang Island  Malaysia  5.411938  100.32664
# 10     17681073            Penang Island  Malaysia  5.411938  100.32664
# 11     17681076            Penang Island  Malaysia  5.411938  100.32664
# 12     17645039            Penang Island  Malaysia  5.411938  100.32664
# 13     16912725            Penang Island  Malaysia  5.411938  100.32664
# 14     17418910            Penang Island  Malaysia  5.411938  100.32664
# 15     19403709                 Selangor  Malaysia  3.039726  101.44049
# 16     19403707                 Selangor  Malaysia  3.039726  101.44049
# 17     19403708                 Selangor  Malaysia  3.039726  101.44049
# 18     19770151                 Selangor  Malaysia  3.039726  101.44049
# 19     19770221                 Selangor  Malaysia  3.039726  101.44049
# 20     19770179                 Selangor  Malaysia  3.039726  101.44049
# 21     19770323                 Selangor  Malaysia  3.039726  101.44049
# 22     19770141                 Selangor  Malaysia  3.039726  101.44049
# 4245                  Jalan-Jalan At Kampong Bharu Tour    41.21    -1.0
# 4246  4 In 1 Day Tour Elephants, Batu Caves, Monkeys...   618.16    -1.0
# 4247  Kuala Selangor Firefly Boat Tour Including Dinner   276.11    -1.0
# 4248  Historical Malacca Chauffeur Tour by Local - 1...   272.16    -1.0
# 4249    Private Malacca Day Trip (Price Based Per Car)    927.24    -1.0
# 4250      MALACCA DAY TOUR PRIVATE with PERANAKAN LUNCH   329.68    -1.0
# 4251               Loagan Bunut National Park Excursion   411.69    -1.0
# 4252                   Miri Airport Transfer- Departure    86.54    -1.0
# 4253                     Miri Airport Transfer- Arrival    86.54    -1.0
# 4254  Experience Malaysia: Authentic Malaysia Cookin...   549.67     4.5
# 4255  Base On per Vehicle Price To KL Tour Cruise Ex...   679.88    -1.0
# 4256                Private Tour Colourful Night I-City   154.95     5.0
#
# [4257 rows x 10 columns]

# %%
attr_rating_spark_df.createOrReplaceTempView('final_attr_spark_df')

# %% [markdown]
# # Processing price

# %%
attr_price_spark_df = final_attr_spark_df

# %%
avg_price_spark_df = spark.sql(
    "SELECT city, category, AVG(price) as avg_price FROM final_attr_spark_df GROUP BY city, category"
)
avg_price_spark_df.show()
# Out:
# +--------------+--------------------+------------------+
# |          city|            category|         avg_price|
# +--------------+--------------------+------------------+
# |   bayan_lepas|[transfers_ground...|           144.235|
# |         klang|[transfers_ground...|239.02500000000003|
# |          kuah|[private_custom_t...|            298.78|
# |  kuala_lumpur|[shopping_fashion...|150.42000000000002|
# | pantai_cenang|[cruises_sailing_...|            149.39|
# |    port_klang|[weddings_honeymo...|            618.16|
# |   george_town|[luxury_special_o...|           169.748|
# |   george_town|[shore_excursions...|             370.9|
# |         klang|[shore_excursions...|377.67049999999995|
# |  kuala_lumpur|[luxury_special_o...|132.54684210526318|
# |kuala_selangor|[day_trips_excurs...|            273.23|
# |      langkawi|[family_friendly,...|             36.99|
# |      langkawi|[food_wine_nightl...|             200.9|
# |        melaka| [tours_sightseeing]|            617.51|
# |        pahang|[food_wine_nightl...|            350.29|
# | kota_kinabalu|[cruises_sailing_...|            239.02|
# |        sepang|[multiday_extende...|            379.14|
# |      kelantan|[transfers_ground...| 69.37333333333333|
# |         klang|[shore_excursions...|            309.08|
# | kota_kinabalu|[cruises_sailing_...|           4121.06|
# +--------------+--------------------+------------------+
# only showing top 20 rows

# %%
round_price_udf = functions.udf(lambda x: round(x, 2), DoubleType())

# %%
avg_price_spark_df = avg_price_spark_df.withColumn(
    'updated_price', round_price_udf(avg_price_spark_df["avg_price"]))
avg_price_spark_df.show()
# Out:
# +--------------+--------------------+------------------+-------------+
# |          city|            category|         avg_price|updated_price|
# +--------------+--------------------+------------------+-------------+
# |   bayan_lepas|[transfers_ground...|           144.235|       144.24|
# |         klang|[transfers_ground...|239.02500000000003|       239.03|
# |          kuah|[private_custom_t...|            298.78|       298.78|
# |  kuala_lumpur|[shopping_fashion...|150.42000000000002|       150.42|
# | pantai_cenang|[cruises_sailing_...|            149.39|       149.39|
# |    port_klang|[weddings_honeymo...|            618.16|       618.16|
# |   george_town|[luxury_special_o...|           169.748|       169.75|
# |   george_town|[shore_excursions...|             370.9|        370.9|
# |         klang|[shore_excursions...|377.67049999999995|       377.67|
# |  kuala_lumpur|[luxury_special_o...|132.54684210526318|       132.55|
# |kuala_selangor|[day_trips_excurs...|            273.23|       273.23|
# |      langkawi|[family_friendly,...|             36.99|        36.99|
# |      langkawi|[food_wine_nightl...|             200.9|        200.9|
# |        melaka| [tours_sightseeing]|            617.51|       617.51|
# |        pahang|[food_wine_nightl...|            350.29|       350.29|
# | kota_kinabalu|[cruises_sailing_...|            239.02|       239.02|
# |        sepang|[multiday_extende...|            379.14|       379.14|
# |      kelantan|[transfers_ground...| 69.37333333333333|        69.37|
# |         klang|[shore_excursions...|            309.08|       309.08|
# | kota_kinabalu|[cruises_sailing_...|           4121.06|      4121.06|
# +--------------+--------------------+------------------+-------------+
# only showing top 20 rows

# %%
attr_price_spark_df = attr_price_spark_df.join(avg_price_spark_df,
                                               ['city', 'category'],
                                               'left_outer')

# %%
attr_price_spark_df = attr_price_spark_df.withColumn(
    "price",
    functions.when(attr_price_spark_df["price"] == -1,
                   attr_price_spark_df["updated_price"]).otherwise(
                       attr_price_spark_df["price"])).drop(
                           'updated_price', 'avg_price')

# %%
# show null row from spark dataframe basec on specific column
attr_price_spark_df.where(attr_price_spark_df.price.isNull()).show()
attr_price_spark_df.count()
# Out:
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# |city|category|activityId|state|country|latitude|longitude|name|price|rating|
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# +----+--------+----------+-----+-------+--------+---------+----+-----+------+
# 4257

# %%
display(attr_price_spark_df.toPandas())
# Out:
#                 city                                           category  \
# 0        bayan_lepas                       [transfers_ground_transport]
# 1        bayan_lepas                       [transfers_ground_transport]
# 2              klang                       [transfers_ground_transport]
# 3              klang                       [transfers_ground_transport]
# 4               kuah  [private_custom_tours, luxury_special_occasion...
# 5       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 6       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 7      pantai_cenang  [cruises_sailing_water_tours, luxury_special_o...
# 8         port_klang                              [weddings_honeymoons]
# 9        george_town  [luxury_special_occasions, cultural_theme_tour...
# 10       george_town  [luxury_special_occasions, cultural_theme_tour...
# 11       george_town  [luxury_special_occasions, cultural_theme_tour...
# 12       george_town  [luxury_special_occasions, cultural_theme_tour...
# 13       george_town  [luxury_special_occasions, cultural_theme_tour...
# 14       george_town  [shore_excursions, luxury_special_occasions, d...
# 15             klang  [shore_excursions, day_trips_excursions, priva...
# 16             klang  [shore_excursions, day_trips_excursions, priva...
# 17             klang  [shore_excursions, day_trips_excursions, priva...
# 18             klang  [shore_excursions, day_trips_excursions, priva...
# 19             klang  [shore_excursions, day_trips_excursions, priva...
# 20             klang  [shore_excursions, day_trips_excursions, priva...
# 21             klang  [shore_excursions, day_trips_excursions, priva...
# 22             klang  [shore_excursions, day_trips_excursions, priva...
# 23             klang  [shore_excursions, day_trips_excursions, priva...
# 24             klang  [shore_excursions, day_trips_excursions, priva...
# 25             klang  [shore_excursions, day_trips_excursions, priva...
# 26             klang  [shore_excursions, day_trips_excursions, priva...
# 27             klang  [shore_excursions, day_trips_excursions, priva...
# 28             klang  [shore_excursions, day_trips_excursions, priva...
# 29             klang  [shore_excursions, day_trips_excursions, priva...
# ...              ...                                                ...
# 4227    kuala_lumpur  [private_custom_tours, cultural_theme_tours, t...
# 4228     pulau_carey                 [water_sports, outdoor_activities]
# 4229     george_town  [featured_tours_and_tickets, walking_biking_to...
# 4230   kota_kinabalu     [recommended_experiences, food_wine_nightlife]
# 4231            kuah  [water_sports, recommended_experiences, cruise...
# 4232    kuala_lumpur  [family_friendly, recommended_experiences, lux...
# 4233    kuala_lumpur  [outdoor_activities, luxury_special_occasions,...
# 4234    kuala_lumpur             [tours_sightseeing, tours_sightseeing]
# 4235          pahang  [recommended_experiences, sightseeing_tickets_...
# 4236      alor_setar                       [transfers_ground_transport]
# 4237   kota_kinabalu                               [outdoor_activities]
# 4238   kota_kinabalu                               [outdoor_activities]
# 4239   kota_kinabalu                               [outdoor_activities]
# 4240   kota_kinabalu                               [outdoor_activities]
# 4241   kota_kinabalu                               [outdoor_activities]
# 4242   kota_kinabalu                               [outdoor_activities]
# 4243   kota_kinabalu                               [outdoor_activities]
# 4244    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4245    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4246    kuala_lumpur  [walking_biking_tours, shore_excursions, outdo...
# 4247  kuala_selangor    [sightseeing_tickets_passes, tours_sightseeing]
# 4248          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4249          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4250          melaka  [shore_excursions, cultural_theme_tours, priva...
# 4251            miri  [cruises_sailing_water_tours, outdoor_activiti...
# 4252            miri                       [transfers_ground_transport]
# 4253            miri                       [transfers_ground_transport]
# 4254          penang  [local_experiences, food_wine_nightlife, tours...
# 4255   petaling_jaya  [shore_excursions, private_custom_tours, day_t...
# 4256       shah_alam  [theme_parks, sightseeing_tickets_passes, tour...
#
#      activityId                    state   country  latitude  longitude  \
# 0      19759004            Penang Island  Malaysia  5.294487  100.25968
# 1      19708737            Penang Island  Malaysia  5.294487  100.25968
# 2      19645570                 Selangor  Malaysia  3.039726  101.44049
# 3      19645571                 Selangor  Malaysia  3.039726  101.44049
# 4      13933745                 Langkawi  Malaysia  6.326672  99.843025
# 5      17516062      Wilayah Persekutuan  Malaysia  3.156802  101.69717
# 6      12965235      Wilayah Persekutuan  Malaysia  3.156802  101.69717
# 7      16861212                 Langkawi  Malaysia  6.290657   99.72765
# 8      15342175                 Selangor  Malaysia  2.999852  101.39283
# 9      16878593            Penang Island  Malaysia  5.411938  100.32664
# 4253   17538993            Miri District  Malaysia  4.320708  113.99225
# 4254   12463729                 Malaysia  Malaysia   5.42382  100.32765
# 4255   13805232        Petaling District  Malaysia   3.10363  101.64778
# 4256   17401342        Petaling District  Malaysia   3.09201  101.49428
#
#                                                    name    price  rating
# 0     Private Transfer: Penang International Airport...   164.84     2.0
# 1     Private Transfer: Penang International Airport...   123.63     5.0
# 2     Day Trip from Port Klang Terminal to Kuala Lum...   296.72    -1.0
# 3     SIC Day Trip From Cruise Terminal to KL City t...   181.33    -1.0
# 4     Private Full Day Langkawi City Tour with Under...   298.78    -1.0
# 5     Private Kuala Lumpur Downtown Local Malay Nigh...   156.60    -1.0
# 6                Private Kuala Lumpur Night Market Tour   144.24    -1.0
# 7                         Langkawi Mangrove Forest Tour   149.39    -1.0
# 8                 3 Nights 4 Days Honeymoon in Malaysia   618.16    -1.0
# 9                             Penang Half Day City Tour   101.09     4.0
# 10    Penang Half Day City Tour Including The Top Ko...   218.42     0.0
# 11    Penang Half Day City Tour Including Entopia Bu...   218.42     0.0
# 12     Penang Diversity Historical Religious Site Tours   121.24     0.0
# 13                        Penang Night Tour with Dinner   189.57     0.0
# 14    A Fabulous Day in Penang (Private Tour with Lu...   370.90    -1.0
# 15    Kuala Lumpur Cruise Layover Tour Include All E...   464.90    -1.0
# 16    Kuala Lumpur Shore Excursion: City tour Includ...   508.95    -1.0
# 17    Shore Excursion: Kuala Lumpur Modern and Histo...   464.90    -1.0
# 18    Kuala Lumpur Cruise Excursion: Full Day Sights...   489.38    -1.0
# 19    Shore Excursion: Full-Day Kuala Lumpur Guided ...   489.38    -1.0
# 20    Kuala Lumpur Guided Full-Day Cruise Excursion ...   489.38    -1.0
# 21    Shore Excursion: Guided Batu Caves And Kuala L...   489.38    -1.0
# 22    Kuala Lumpur Cruise Excursion: Guided Amazing ...   489.38    -1.0
# 23     Shore Excursion: Full-Day Kuala Lumpur City Tour   267.87    -1.0
# 24    Kuala Lumpur Full-Day Cruise Excursion Tour Fr...   267.87    -1.0
# 25     Shore Excursion: Full-Day Kuala Lumpur City Tour   267.87    -1.0
# 26    Shore Excursion: Batu Caves And Kuala Lumpur C...   267.87    -1.0
# 27    Shore Excursion: Batu Caves And Kuala Lumpur C...   267.87    -1.0
# 28    Kuala Lumpur Cruise Excursion: Amazing Full Da...   267.87    -1.0
# 29    Kuala Lumpur Cruise Excursion: Full Day Sights...   267.87    -1.0
# ...                                                 ...      ...     ...
# 4227                                    Batu Caves Tour    82.42    -0.5
# 4228                            Family-friendly Fishing   195.75    -1.0
# 4229           Half-Day Penang Countryside Cycling Tour   115.81     5.0
# 4230  Evening Cultural Dance Tour With Dinner in Kot...   242.11    -1.0
# 4231     Pulau Payar Marine Park with Lunch from Penang   494.49     4.0
# 4232  Kuala Lumpur Petronas Twin Towers, Petrosains ...   695.43    -1.0
# 4233     Genting Highland Full Day Tour :Exclusive Deal   107.15    -1.0
# 4234  Kuala Lumpur Cruise Layover Tour from Boustead...   387.38    -1.0
# 4235                      Malacca 3Days 2Nights Package  2114.10    -1.0
# 4236  (private Transfer) Sultan Abdul Halim Airport ...    70.06    -1.0
# 4237             Mount Kinabalu Climbing 2 Days 1 Night  2678.69     5.0
# 4238    2d1n Mount Kinabalu Via Ferrata - Walk The Torq  2967.16     5.0
# 4239                3 Days 2 Night Mount Kinabalu Climb  3708.95     2.5
# 4240  Top of the World - Sunrise Leisure Hike St. Ve...   313.95     5.0
# 4241                       2D1N Mount Kinabalu Climbing  2555.06     5.0
# 4242  Borneo Marine Conservation Experience - Save o...  1219.83     2.5
# 4243            Mount Kinabalu Climbing 3 Days 2 Nights  2958.92     2.5
# 4244  Royal Klang Town Heritage Walk Tour from Kuala...   300.84    -1.0
# 4245                  Jalan-Jalan At Kampong Bharu Tour    41.21    -1.0
# 4246  4 In 1 Day Tour Elephants, Batu Caves, Monkeys...   618.16    -1.0
# 4247  Kuala Selangor Firefly Boat Tour Including Dinner   276.11    -1.0
# 4248  Historical Malacca Chauffeur Tour by Local - 1...   272.16    -1.0
# 4249    Private Malacca Day Trip (Price Based Per Car)    927.24    -1.0
# 4250      MALACCA DAY TOUR PRIVATE with PERANAKAN LUNCH   329.68    -1.0
# 4251               Loagan Bunut National Park Excursion   411.69    -1.0
# 4252                   Miri Airport Transfer- Departure    86.54    -1.0
# 4253                     Miri Airport Transfer- Arrival    86.54    -1.0
# 4254  Experience Malaysia: Authentic Malaysia Cookin...   549.67     4.5
# 4255  Base On per Vehicle Price To KL Tour Cruise Ex...   679.88    -1.0
# 4256                Private Tour Colourful Night I-City   154.95     5.0
#
# [4257 rows x 10 columns]

# %%
attr_price_spark_df.createOrReplaceTempView('final_attr_spark_df')

# %% [markdown]
# # Processing geo coordinates

# %%
attr_geo_spark_df = final_attr_spark_df

# %%
avg_geo_spark_df = spark.sql(
    "SELECT city, category, AVG(latitude) as lat, AVG(longitude) as lng FROM final_attr_spark_df GROUP BY city, category"
)
avg_geo_spark_df.show()
# Out:
# +--------------+--------------------+------------------+------------------+
# |          city|            category|               lat|               lng|
# +--------------+--------------------+------------------+------------------+
# |   bayan_lepas|[transfers_ground...|          5.294487|         100.25968|
# |         klang|[transfers_ground...|          3.039726|         101.44049|
# |          kuah|[private_custom_t...|          6.326672|         99.843025|
# |  kuala_lumpur|[shopping_fashion...|          3.156802|         101.69717|
# | pantai_cenang|[cruises_sailing_...|          6.290657|          99.72765|
# |    port_klang|[weddings_honeymo...|          2.999852|         101.39283|
# |   george_town|[luxury_special_o...|          5.411938|         100.32664|
# |   george_town|[shore_excursions...|          5.411938|         100.32664|
# |         klang|[shore_excursions...| 3.039726000000001|101.44048999999997|
# |  kuala_lumpur|[luxury_special_o...|3.1568019999999994|101.69716999999996|
# |kuala_selangor|[day_trips_excurs...|            3.3405|         101.25001|
# |      langkawi|[family_friendly,...|          6.351074|          99.75824|
# |      langkawi|[food_wine_nightl...|          6.351074|          99.75824|
# |        melaka| [tours_sightseeing]|          2.206847|         102.25327|
# |        pahang|[food_wine_nightl...|           3.62074|         102.59239|
# | kota_kinabalu|[cruises_sailing_...|          5.979383|         116.07349|
# |        sepang|[multiday_extende...|           2.69093|         101.75114|
# |      kelantan|[transfers_ground...|           6.13544|         102.23671|
# |         klang|[shore_excursions...|          3.039726|         101.44049|
# | kota_kinabalu|[cruises_sailing_...|          5.979383|         116.07349|
# +--------------+--------------------+------------------+------------------+
# only showing top 20 rows

# %%
attr_geo_spark_df = attr_geo_spark_df.join(avg_geo_spark_df,
                                           ['city', 'category'], 'left_outer')

# %%
attr_geo_spark_df = attr_geo_spark_df.withColumn(
    'latitude',
    functions.when(attr_geo_spark_df['latitude'].isNull(),
                   attr_geo_spark_df['lat']).otherwise(
                       attr_geo_spark_df['latitude'])).withColumn(
                           'longitude',
                           functions.when(
                               attr_geo_spark_df['longitude'].isNull(),
                               attr_geo_spark_df['lng']).otherwise(
                                   attr_geo_spark_df['longitude'])).drop(
                                       attr_geo_spark_df['lat']).drop(
                                           attr_geo_spark_df['lng'])

# %%
# show null row from spark dataframe basec on specific column
display(
    attr_geo_spark_df.where(attr_geo_spark_df.latitude.isNull()).toPandas())
display(
    attr_geo_spark_df.where(attr_geo_spark_df.longitude.isNull()).toPandas())
attr_geo_spark_df.count()
# Out:
#            city                          category activityId            state  \
# 0  pulau_tioman  [shore_excursions, water_sports]   19709623  Rompin District
# 1  pulau_tioman                    [water_sports]   19773031  Rompin District
#
#     country latitude longitude                            name    price  \
# 0  Malaysia     None      None               Scuba in Malaysia   144.24
# 1  Malaysia     None      None  Scuba Diving Course Open Water  1203.35
#
#    rating
# 0    -1.0
# 1    -1.0
#            city                          category activityId            state  \
# 0  pulau_tioman  [shore_excursions, water_sports]   19709623  Rompin District
# 1  pulau_tioman                    [water_sports]   19773031  Rompin District
#
#     country latitude longitude                            name    price  \
# 0  Malaysia     None      None               Scuba in Malaysia   144.24
# 1  Malaysia     None      None  Scuba Diving Course Open Water  1203.35
#
#    rating
# 0    -1.0
# 1    -1.0
# 4257

# %%
display(attr_geo_spark_df.toPandas())
# Out:
#                 city                                           category  \
# 0        bayan_lepas                       [transfers_ground_transport]
# 1        bayan_lepas                       [transfers_ground_transport]
# 2              klang                       [transfers_ground_transport]
# 3              klang                       [transfers_ground_transport]
# 4               kuah  [private_custom_tours, luxury_special_occasion...
# 5       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 6       kuala_lumpur  [shopping_fashion, food_wine_nightlife, privat...
# 7      pantai_cenang  [cruises_sailing_water_tours, luxury_special_o...
# 8         port_klang                              [weddings_honeymoons]
# 9        george_town  [luxury_special_occasions, cultural_theme_tour...
# 10       george_town  [luxury_special_occasions, cultural_theme_tour...
# 11       george_town  [luxury_special_occasions, cultural_theme_tour...
# 12       george_town  [luxury_special_occasions, cultural_theme_tour...
# 13       george_town  [luxury_special_occasions, cultural_theme_tour...
# 14       george_town  [shore_excursions, luxury_special_occasions, d...
# 15             klang  [shore_excursions, day_trips_excursions, priva...
# 16             klang  [shore_excursions, day_trips_excursions, priva...
# 17             klang  [shore_excursions, day_trips_excursions, priva...
# 18             klang  [shore_excursions, day_trips_excursions, priva...
# 19             klang  [shore_excursions, day_trips_excursions, priva...
# 20             klang  [shore_excursions, day_trips_excursions, priva...
# 21             klang  [shore_excursions, day_trips_excursions, priva...
# 22             klang  [shore_excursions, day_trips_excursions, priva...
# 23             klang  [shore_excursions, day_trips_excursions, priva...
# 24             klang  [shore_excursions, day_trips_excursions, priva...
# 25             klang  [shore_excursions, day_trips_excursions, priva...
# 26             klang  [shore_excursions, day_trips_excursions, priva...
# 27             klang  [shore_excursions, day_trips_excursions, priva...
# 28             klang  [shore_excursions, day_trips_excursions, priva...
# 29             klang  [shore_excursions, day_trips_excursions, priva...
# ...              ...                                                ...
# 4227    kuala_lumpur  [private_custom_tours, cultural_theme_tours, t...
# 4228     pulau_carey                 [water_sports, outdoor_activities]
# 4229     george_town  [featured_tours_and_tickets, walking_biking_to...
# 4230   kota_kinabalu     [recommended_experiences, food_wine_nightlife]
# 4231            kuah  [water_sports, recommended_experiences, cruise...
# 4232    kuala_lumpur  [family_friendly, recommended_experiences, lux...
# 4233    kuala_lumpur  [outdoor_activities, luxury_special_occasions,...
# 4234    kuala_lumpur             [tours_sightseeing, tours_sightseeing]
# 4235          pahang  [recommended_experiences, sightseeing_tickets_...
# 4236      alor_setar                       [transfers_ground_transport]
# 4237   kota_kinabalu                               [outdoor_activities]
# 4238   kota_kinabalu                               [outdoor_activities]
# 4239   kota_kinabalu                               [outdoor_activities]
# 4240   kota_kinabalu                               [outdoor_activities]
# 4241   kota_kinabalu                               [outdoor_activities]
# 4242   kota_kinabalu                               [outdoor_activities]
# 4243   kota_kinabalu                               [outdoor_activities]
# 4244    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4245    kuala_lumpur  [walking_biking_tours, luxury_special_occasion...
# 4246    kuala_lumpur  [walking_biking_tours, shore_excursions, outdo...
# 4247  kuala_selangor    [sightseeing_tickets_passes, tours_sightseeing]
# 4248          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4249          melaka  [luxury_special_occasions, cultural_theme_tour...
# 4250          melaka  [shore_excursions, cultural_theme_tours, priva...
# 4251            miri  [cruises_sailing_water_tours, outdoor_activiti...
# 4252            miri                       [transfers_ground_transport]
# 4253            miri                       [transfers_ground_transport]
# 4254          penang  [local_experiences, food_wine_nightlife, tours...
# 4255   petaling_jaya  [shore_excursions, private_custom_tours, day_t...
# 4256       shah_alam  [theme_parks, sightseeing_tickets_passes, tour...
#
#      activityId                    state   country  latitude  longitude  \
# 0      19759004            Penang Island  Malaysia  5.294487  100.25968
# 1      19708737            Penang Island  Malaysia  5.294487  100.25968
# 2      19645570                 Selangor  Malaysia  3.039726  101.44049
# 3      19645571                 Selangor  Malaysia  3.039726  101.44049
# 4      13933745                 Langkawi  Malaysia  6.326672  99.843025
# 4247   17715717                 Selangor  Malaysia    3.3405  101.25001
# 4248   19010048  Central Melaka District  Malaysia  2.206847  102.25327
# 4249   18935428  Central Melaka District  Malaysia  2.206847  102.25327
# 4250   17330148  Central Melaka District  Malaysia  2.206847  102.25327
# 4251   19422586            Miri District  Malaysia  4.320708  113.99225
# 4252   17538991            Miri District  Malaysia  4.320708  113.99225
# 4253   17538993            Miri District  Malaysia  4.320708  113.99225
# 4254   12463729                 Malaysia  Malaysia   5.42382  100.32765
# 4255   13805232        Petaling District  Malaysia   3.10363  101.64778
# 4256   17401342        Petaling District  Malaysia   3.09201  101.49428
#
#                                                    name    price  rating
# 0     Private Transfer: Penang International Airport...   164.84     2.0
# 1     Private Transfer: Penang International Airport...   123.63     5.0
# 2     Day Trip from Port Klang Terminal to Kuala Lum...   296.72    -1.0
# 3     SIC Day Trip From Cruise Terminal to KL City t...   181.33    -1.0
# 4     Private Full Day Langkawi City Tour with Under...   298.78    -1.0
# 5     Private Kuala Lumpur Downtown Local Malay Nigh...   156.60    -1.0
# 6                Private Kuala Lumpur Night Market Tour   144.24    -1.0
# 7                         Langkawi Mangrove Forest Tour   149.39    -1.0
# 8                 3 Nights 4 Days Honeymoon in Malaysia   618.16    -1.0
# 9                             Penang Half Day City Tour   101.09     4.0
# 10    Penang Half Day City Tour Including The Top Ko...   218.42     0.0
# 11    Penang Half Day City Tour Including Entopia Bu...   218.42     0.0
# 12     Penang Diversity Historical Religious Site Tours   121.24     0.0
# 13                        Penang Night Tour with Dinner   189.57     0.0
# 14    A Fabulous Day in Penang (Private Tour with Lu...   370.90    -1.0
# 15    Kuala Lumpur Cruise Layover Tour Include All E...   464.90    -1.0
# 16    Kuala Lumpur Shore Excursion: City tour Includ...   508.95    -1.0
# 17    Shore Excursion: Kuala Lumpur Modern and Histo...   464.90    -1.0
# 18    Kuala Lumpur Cruise Excursion: Full Day Sights...   489.38    -1.0
# 19    Shore Excursion: Full-Day Kuala Lumpur Guided ...   489.38    -1.0
# 20    Kuala Lumpur Guided Full-Day Cruise Excursion ...   489.38    -1.0
# 21    Shore Excursion: Guided Batu Caves And Kuala L...   489.38    -1.0
# 22    Kuala Lumpur Cruise Excursion: Guided Amazing ...   489.38    -1.0
# 23     Shore Excursion: Full-Day Kuala Lumpur City Tour   267.87    -1.0
# 24    Kuala Lumpur Full-Day Cruise Excursion Tour Fr...   267.87    -1.0
# 25     Shore Excursion: Full-Day Kuala Lumpur City Tour   267.87    -1.0
# 26    Shore Excursion: Batu Caves And Kuala Lumpur C...   267.87    -1.0
# 27    Shore Excursion: Batu Caves And Kuala Lumpur C...   267.87    -1.0
# 28    Kuala Lumpur Cruise Excursion: Amazing Full Da...   267.87    -1.0
# 29    Kuala Lumpur Cruise Excursion: Full Day Sights...   267.87    -1.0
# ...                                                 ...      ...     ...
# 4227                                    Batu Caves Tour    82.42    -0.5
# 4228                            Family-friendly Fishing   195.75    -1.0
# 4229           Half-Day Penang Countryside Cycling Tour   115.81     5.0
# 4230  Evening Cultural Dance Tour With Dinner in Kot...   242.11    -1.0
# 4231     Pulau Payar Marine Park with Lunch from Penang   494.49     4.0
# 4232  Kuala Lumpur Petronas Twin Towers, Petrosains ...   695.43    -1.0
# 4233     Genting Highland Full Day Tour :Exclusive Deal   107.15    -1.0
# 4234  Kuala Lumpur Cruise Layover Tour from Boustead...   387.38    -1.0
# 4235                      Malacca 3Days 2Nights Package  2114.10    -1.0
# 4236  (private Transfer) Sultan Abdul Halim Airport ...    70.06    -1.0
# 4237             Mount Kinabalu Climbing 2 Days 1 Night  2678.69     5.0
# 4238    2d1n Mount Kinabalu Via Ferrata - Walk The Torq  2967.16     5.0
# 4239                3 Days 2 Night Mount Kinabalu Climb  3708.95     2.5
# 4240  Top of the World - Sunrise Leisure Hike St. Ve...   313.95     5.0
# 4241                       2D1N Mount Kinabalu Climbing  2555.06     5.0
# 4242  Borneo Marine Conservation Experience - Save o...  1219.83     2.5
# 4243            Mount Kinabalu Climbing 3 Days 2 Nights  2958.92     2.5
# 4244  Royal Klang Town Heritage Walk Tour from Kuala...   300.84    -1.0
# 4245                  Jalan-Jalan At Kampong Bharu Tour    41.21    -1.0
# 4246  4 In 1 Day Tour Elephants, Batu Caves, Monkeys...   618.16    -1.0
# 4247  Kuala Selangor Firefly Boat Tour Including Dinner   276.11    -1.0
# 4248  Historical Malacca Chauffeur Tour by Local - 1...   272.16    -1.0
# 4249    Private Malacca Day Trip (Price Based Per Car)    927.24    -1.0
# 4250      MALACCA DAY TOUR PRIVATE with PERANAKAN LUNCH   329.68    -1.0
# 4251               Loagan Bunut National Park Excursion   411.69    -1.0
# 4252                   Miri Airport Transfer- Departure    86.54    -1.0
# 4253                     Miri Airport Transfer- Arrival    86.54    -1.0
# 4254  Experience Malaysia: Authentic Malaysia Cookin...   549.67     4.5
# 4255  Base On per Vehicle Price To KL Tour Cruise Ex...   679.88    -1.0
# 4256                Private Tour Colourful Night I-City   154.95     5.0
#
# [4257 rows x 10 columns]

# %%
attr_geo_spark_df.createOrReplaceTempView('final_attr_spark_df')

# %%
import googlemaps
import os

# %%
def get_geocode(place):
    gmaps = googlemaps.Client(key=os.environ['GOOGLE_API_KEY'])
    place = gmaps.places(place)
    geocode = {
        'lat': place["results"][0]["geometry"]["location"]["lat"],
        'lng': place["results"][0]["geometry"]["location"]["lng"]
    }
    return geocode

# %%
get_lat_udf = functions.udf(lambda x: get_geocode(x)['lat'], StringType())
get_lng_udf = functions.udf(lambda x: get_geocode(x)['lng'], StringType())

# %%
attr_geo_spark_df = attr_geo_spark_df.withColumn(
    'latitude',
    functions.when(attr_geo_spark_df['latitude'].isNull(),
                   get_lat_udf(attr_geo_spark_df['city'])).otherwise(
                       attr_geo_spark_df['latitude']))

attr_geo_spark_df = attr_geo_spark_df.withColumn(
    'longitude',
    functions.when(attr_geo_spark_df['longitude'].isNull(),
                   get_lng_udf(attr_geo_spark_df['city'])).otherwise(
                       attr_geo_spark_df['longitude']))
